# %%
import pymongo as pm
from pymongo import MongoClient
import pprint as pp
import re
import numpy as np

# %%
cluster = MongoClient("mongodb://localhost:27017")

# %%
print(cluster)
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = cluster['Plagchecker_local']

# %%
lc_col = db.get_collection('leetcode_solutions')

# %%
sub_col = db.get_collection('csi_submissions')

# %%
# for i in question_numbers:
#     curr_qn = i
#     for j in lang:
#         email_list = []
       
#         for sub in sub_col.find({'$and': [
#                                 {'language': {'$regex': j, '$options': 'i'}},
#                                 {'questionNumber': curr_qn},
#                                 {'email': '1032211976@mitwpu.edu.in'}
#                                 ]}):

#             email = sub['email']
#             text = sub['code']
#             print('\n\n\n --- The Code --- \n\n\n {}'.format(text))
#             print(f"Email: {email}")
#             email_list.append(email)
#             # pp.pprint(sub)

lang = ['^java$', '^python$', '^c$', '^c\\+\\+$']
question_numbers = [9, 69, 190, 141, 605, 290, 4, 11, 17, 38, 283, 70, 242, 206, 230, 54, 567, 51, 127, 875, 402]


def query_for_email(k):
    query_1 = {
            'language': {'$regex': j, '$options': 'i'},
            'questionNumber': i,
            'email': k
        }
    for sub in sub_col.find(query_1):
        code = sub['code']

    return code

for i in question_numbers:
    curr_qn = i
    for j in lang:
        email_list = []
       
        for sub in sub_col.find({'$and': [
                                {'language': {'$regex': j, '$options': 'i'}},
                                {'questionNumber': curr_qn}
                                ]})

            email = sub['email']
            text = sub['code']
            # print('\n\n\n --- The Code --- \n\n\n {}'.format(text))
            # print(f"Email: {email}")
            email_list.append(email)
            # pp.pprint(sub)

        # print("\n\n ----------------- End of 1 language {}------------- \n\n".format(j))
        query = {
            'language': {'$regex': j, '$options': 'i'},
            'questionNumber': i
        }

        for k in email_list:
            text1_email = k
            for l in email_list:
                code = query_for_email(l)


        result_count = sub_col.count_documents(query)
        print('\n \n  ----  Question number {} and Language {} the count {} ---- \n \n'.format(curr_qn, j, result_count))
        # print(email_list)

# %%
lang = ['^java$', '^python$', '^c$', '^c\\+\\+$']
question_numbers = [9, 69, 190, 141, 605, 290, 4, 11, 17, 38, 283, 70, 242, 206, 230, 54, 567, 51, 127, 875, 402]
# Out:
#
#   ----  Question number 9 and Language ^java$ the count 20 ----
#
#
#
#
#   ----  Question number 9 and Language ^python$ the count 19 ----
#
#
#
#
#   ----  Question number 9 and Language ^c$ the count 17 ----
#
#
#
#
#   ----  Question number 9 and Language ^c\+\+$ the count 44 ----
#
#
#
#
#   ----  Question number 69 and Language ^java$ the count 14 ----
#
#
#
#
#   ----  Question number 69 and Language ^python$ the count 14 ----
#
#
#
#
#   ----  Question number 69 and Language ^c$ the count 9 ----
#
#
#
#
#   ----  Question number 69 and Language ^c\+\+$ the count 34 ----
#
#
#
#
#   ----  Question number 190 and Language ^java$ the count 10 ----
#
#
#
#
#   ----  Question number 190 and Language ^python$ the count 7 ----
#
#
#
#
#   ----  Question number 190 and Language ^c$ the count 6 ----
#
#
#
#
#   ----  Question number 190 and Language ^c\+\+$ the count 31 ----
#
#
#
#
#   ----  Question number 141 and Language ^java$ the count 11 ----
#
#
#
#
#   ----  Question number 141 and Language ^python$ the count 6 ----
#
#
#
#
#   ----  Question number 141 and Language ^c$ the count 6 ----
#
#
#
#
#   ----  Question number 141 and Language ^c\+\+$ the count 25 ----
#
#
#
#
#   ----  Question number 605 and Language ^java$ the count 10 ----
#
#
#
#
#   ----  Question number 605 and Language ^python$ the count 9 ----
#
#
#
#
#   ----  Question number 605 and Language ^c$ the count 1 ----
#
#
#
#
#   ----  Question number 605 and Language ^c\+\+$ the count 18 ----
#
#
#
#
#   ----  Question number 290 and Language ^java$ the count 9 ----
#
#
#
#
#   ----  Question number 290 and Language ^python$ the count 9 ----
#
#
#
#
#   ----  Question number 290 and Language ^c$ the count 0 ----
#
#
#
#
#   ----  Question number 290 and Language ^c\+\+$ the count 16 ----
#
#
#
#
#   ----  Question number 4 and Language ^java$ the count 7 ----
#
#
#
#
#   ----  Question number 4 and Language ^python$ the count 7 ----
#
#
#
#
#   ----  Question number 4 and Language ^c$ the count 0 ----
#
#
#
#
#   ----  Question number 4 and Language ^c\+\+$ the count 16 ----
#
#
#
#
#   ----  Question number 11 and Language ^java$ the count 9 ----
#
#
#
#
#   ----  Question number 11 and Language ^python$ the count 9 ----
#
#
#
#
#   ----  Question number 11 and Language ^c$ the count 1 ----
#
#
#
#
#   ----  Question number 11 and Language ^c\+\+$ the count 12 ----
#
#
#
#
#   ----  Question number 17 and Language ^java$ the count 6 ----
#
#
#
#
#   ----  Question number 17 and Language ^python$ the count 11 ----
#
#
#
#
#   ----  Question number 17 and Language ^c$ the count 0 ----
#
#
#
#
#   ----  Question number 17 and Language ^c\+\+$ the count 9 ----
#
#
#
#
#   ----  Question number 38 and Language ^java$ the count 8 ----
#
#
#
#
#   ----  Question number 38 and Language ^python$ the count 5 ----
#
#
#
#
#   ----  Question number 38 and Language ^c$ the count 0 ----
#
#
#
#
#   ----  Question number 38 and Language ^c\+\+$ the count 12 ----
#
#
#
#
#   ----  Question number 283 and Language ^java$ the count 13 ----
#
#
#
#
#   ----  Question number 283 and Language ^python$ the count 9 ----
#
#
#
#
#   ----  Question number 283 and Language ^c$ the count 1 ----
#
#
#
#
#   ----  Question number 283 and Language ^c\+\+$ the count 13 ----
#
#
#
#
#   ----  Question number 70 and Language ^java$ the count 5 ----
#
#
#
#
#   ----  Question number 70 and Language ^python$ the count 5 ----
#
#
#
#
#   ----  Question number 70 and Language ^c$ the count 1 ----
#
#
#
#
#   ----  Question number 70 and Language ^c\+\+$ the count 8 ----
#
#
#
#
#   ----  Question number 242 and Language ^java$ the count 9 ----
#
#
#
#
#   ----  Question number 242 and Language ^python$ the count 6 ----
#
#
#
#
#   ----  Question number 242 and Language ^c$ the count 0 ----
#
#
#
#
#   ----  Question number 242 and Language ^c\+\+$ the count 8 ----
#
#
#
#
#   ----  Question number 206 and Language ^java$ the count 9 ----
#
#
#
#
#   ----  Question number 206 and Language ^python$ the count 5 ----
#
#
#
#
#   ----  Question number 206 and Language ^c$ the count 0 ----
#
#
#
#
#   ----  Question number 206 and Language ^c\+\+$ the count 8 ----
#
#
#
#
#   ----  Question number 230 and Language ^java$ the count 9 ----
#
#
#
#
#   ----  Question number 230 and Language ^python$ the count 5 ----
#
#
#
#
#   ----  Question number 230 and Language ^c$ the count 0 ----
#
#
#
#
#   ----  Question number 230 and Language ^c\+\+$ the count 7 ----
#
#
#
#
#   ----  Question number 54 and Language ^java$ the count 6 ----
#
#
#
#
#   ----  Question number 54 and Language ^python$ the count 3 ----
#
#
#
#
#   ----  Question number 54 and Language ^c$ the count 0 ----
#
#
#
#
#   ----  Question number 54 and Language ^c\+\+$ the count 9 ----
#
#
#
#
#   ----  Question number 567 and Language ^java$ the count 7 ----
#
#
#
#
#   ----  Question number 567 and Language ^python$ the count 3 ----
#
#
#
#
#   ----  Question number 567 and Language ^c$ the count 0 ----
#
#
#
#
#   ----  Question number 567 and Language ^c\+\+$ the count 7 ----
#
#
#
#
#   ----  Question number 51 and Language ^java$ the count 4 ----
#
#
#
#
#   ----  Question number 51 and Language ^python$ the count 5 ----
#
#
#
#
#   ----  Question number 51 and Language ^c$ the count 0 ----
#
#
#
#
#   ----  Question number 51 and Language ^c\+\+$ the count 5 ----
#
#
#
#
#   ----  Question number 127 and Language ^java$ the count 5 ----
#
#
#
#
#   ----  Question number 127 and Language ^python$ the count 3 ----
#
#
#
#
#   ----  Question number 127 and Language ^c$ the count 0 ----
#
#
#
#
#   ----  Question number 127 and Language ^c\+\+$ the count 5 ----
#
#
#
#
#   ----  Question number 875 and Language ^java$ the count 5 ----
#
#
#
#
#   ----  Question number 875 and Language ^python$ the count 3 ----
#
#
#
#
#   ----  Question number 875 and Language ^c$ the count 0 ----
#
#
#
#
#   ----  Question number 875 and Language ^c\+\+$ the count 7 ----
#
#
#
#
#   ----  Question number 402 and Language ^java$ the count 4 ----
#
#
#
#
#   ----  Question number 402 and Language ^python$ the count 3 ----
#
#
#
#
#   ----  Question number 402 and Language ^c$ the count 0 ----
#
#
#
#
#   ----  Question number 402 and Language ^c\+\+$ the count 7 ----

# %%
results = np.zeros((3,3))

# %%
results[0][0] = 1
results[0][2] = 4

# %%
np.where(results == 4)[0]
# Out:
# array([0])

# %%
def jaccard_similarity(doc1, doc2):
    # Convert fingerprints to sets
    set_doc1 = set(doc1)
    set_doc2 = set(doc2)
    
    # Calculate Jaccard similarity
    jaccard_sim = len(set_doc1.intersection(set_doc2)) / len(set_doc1.union(set_doc2))
    
    return jaccard_sim

def check_similarity(fp_doc1, fp_doc2, threshold=0.4):
    
    jaccard_sim = jaccard_similarity(fp_doc1, fp_doc2)
    
    # if jaccard_sim > threshold:
    #     print("Documents are similar")
    # else:
    #     print("Documents are dissimilar")
        
    perc_similar = jaccard_sim * 100
    return perc_similar

text1 = "public class main {	public static void main(String[] args) {		System.out.println(factorial(10));	}	public static int factorial(int n)    {		int ret = 1;        for (int i = 1; i <= n; ++i) ret *= i;        return ret;    }}"
text2 = "	public class main {		static int currentFactor = 1;		static int currentResult = 1;		public static void main(String[] args) {			System.out.println(factorial(10));		}		public static int factorial(int n)     {			fac:			while(currentFactor!=n) {				currentResult *= currentFactor;				continue fac;			}			return currentResult;	    }	}"
fp2 = winnowing_fingerprint(text2) # fingerprints of doc 2
fp1 = winnowing_fingerprint(text1) # fingerprints of doc 1

# print("Sequence of the first set of hash values : ",fp1)
# print("Sequence of the second set of hash values : ",fp2)

perc_sim = check_similarity(fp1, fp2) 

print("Fingerprint Similarity:", perc_sim, "%")


def offset_difference_comparison(fingerprint1, fingerprint2):
    # Ensure fingerprints are sorted
    fingerprint1.sort()
    fingerprint2.sort()

    # Calculate differences between matching fingerprints
    differences = [abs(x - y) for x, y in zip(fingerprint1, fingerprint2)]

    # Calculate average offset
    average_offset = sum(differences) / len(differences) if differences else 0

    return average_offset

# Example usage:
text1 = "public class main {	public static void main(String[] args) {		System.out.println(factorial(10));	}	public static int factorial(int n)    {		int ret = 1;        for (int i = 1; i <= n; ++i) ret *= i;        return ret;    }}"
text2 = "public class main {	public static void main(String[] args) {		int ret = 1;for (int i = 1; i <= 10; ++i) ret *= i;		System.out.println(ret);	}}"

fp1 = winnowing_fingerprint(text1) # fingerprints of doc 1
fp2 = winnowing_fingerprint(text2) # fingerprints of doc 2
average_offset = offset_difference_comparison(fp1, fp2)
print(f"Average Offset: {average_offset}")

## ------------------------------------WAY TWO--------------------------------------------------

def longest_common_sequence(fingerprint1, fingerprint2):
    # Find the length of the longest common sequence
    common_sequence = []
    current_sequence = []

    for i, fp1 in enumerate(fingerprint1):
        if fp1 in fingerprint2:
            current_sequence.append(fp1)
        else:
            if len(current_sequence) > len(common_sequence):
                common_sequence = current_sequence.copy()
            current_sequence = []

    # Check at the end of the loop
    if len(current_sequence) > len(common_sequence):
        common_sequence = current_sequence

    return common_sequence
# Out:
# mynameisdaanishandi'mtryingoutwinnowing
# Sequence of hash values: [522, 522, 518, 514, 514, 509, 509, 509, 509, 524, 526, 516, 451, 451, 451, 451, 463, 469, 483, 499, 550, 546, 546, 546, 546, 557, 560, 555, 555, 555, 555, 548]
# publicclassmain{staticintcurrentFactor=1;staticintcurrentResult=1;publicstaticvoidmain(String[]args){System.out.println(factorial(10));}publicstaticintfactorial(intn){fac:while(currentFactor!=n){currentResult*=currentFactor;continuefac;}returncurrentResult;}}
# publicclassmain{publicstaticvoidmain(String[]args){System.out.println(factorial(10));}publicstaticintfactorial(intn){intret=1;for(inti=1;i<=n;++i)ret*=i;returnret;}}
# Documents are similar
# Fingerprint Similarity: 45.09803921568628 %
# publicclassmain{publicstaticvoidmain(String[]args){System.out.println(factorial(10));}publicstaticintfactorial(intn){intret=1;for(inti=1;i<=n;++i)ret*=i;returnret;}}
# publicclassmain{publicstaticvoidmain(String[]args){intret=1;for(inti=1;i<=10;++i)ret*=i;System.out.println(ret);}}
# Average Offset: 24.77570093457944
